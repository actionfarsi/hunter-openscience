# %% [markdown]
# # Jupyter test notebook

# %% [markdown]
# ## Write comments
#
# Text cells are written in [markdown](https://guides.github.com/features/mastering-markdown/) format. It's a simple text markup language that gets rendered
#
# To edit this cell, double-click.
# To see observe the changes, shift-enter
#
# You can write
#  - list
#  - unordered
#   1. and ordered
#   2. like this
#
# You can add figures
# ![Import antigravity](http://imgs.xkcd.com/comics/python.png)
#
#
# and math in $\LaTeX$ format $$ \frac{x^2 + y^2 }{z^2} $$

# %% [markdown]
# ## Basic programming (python)

# %% [markdown]
# Indeed you can use the code as a calculator

# %%
# This is a comment
1 + 2
# Out:
# 3

# %% [markdown]
# and assign variables and perform symbolic computation

# %%
a = 3
b = 10
print(a*b+10*b**2)
# Out:
# 1030

# %% [markdown]
# You can also define lists

# %%
my_list = [10,20,30,40,50,60]

print(my_list[3])
print(my_list[1:3])
# Out:
# 40
# [20, 30]

# %% [markdown]
# and numerical arrays (via `numpy`)

# %%
from numpy import *
my_array = array([1,3,5,7,8])
x = linspace(start = 0,stop = 1,  num = 10)

print(x + 3)
# Out:
# [ 3.          3.11111111  3.22222222  3.33333333  3.44444444  3.55555556
#   3.66666667  3.77777778  3.88888889  4.        ]

# %% [markdown]
# ## Basic plotting

# %% [markdown]
# There are several libraries to plot.
# Let's focus on [bokeh](http://bokeh.pydata.org/en/latest/docs/user_guide/quickstart.html#userguide-quickstart) for interactive exploration and beatiful colors

# %%
import bokeh
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
from bokeh.charts import Line
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9f1dbae2-2b8b-4a88-aebe-035515fd6745">Loading BokehJS ...</span>
#     </div>

# %%
x = linspace(0,10,200)
y = x**1/2+sin(x)
y2 = x**-1/2+sin(x)

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Line", line_width=2)
p.circle(x, y2, legend="Circles", line_width=2, color = 'olive')

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="787eae54-1484-45fb-a00f-02a391878e03"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...
